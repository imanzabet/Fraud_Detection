# %%
from fraud_detection.main import preprocessing
import pandas as pd

# notebook settings
import warnings
warnings.filterwarnings("ignore")
pd.options.mode.chained_assignment = None
pd.set_option('display.max_rows', None)
pd.set_option("display.max_columns", None)
# %matplotlib inline

pp = preprocessing()
df = pp.pickle_load(fname='dfPickle_2')

df.head(5)
# Out:
#      index  customerId  creditLimit  availableMoney  transactionAmount  \
# 21      21        2611     0.296562        0.939348           0.450154
# 73      73        2611     0.296562        0.938802           0.169310
# 124    124        4911     1.000000        0.999187           0.538697
# 150    150        4911     1.000000        0.997505           0.541973
# 216    216        4911     1.000000        0.993449           0.347876
#
#      merchantName  acqCountry  merchantCountryCode  posEntryMode  \
# 21            553           3                    3             2
# 73            550           3                    3             1
# 124          1301           3                    3             0
# 150          2234           3                    3             1
# 216          2093           3                    3             0
#
#      posConditionCode  merchantCategoryCode  transactionType  currentBalance  \
# 21                  0                     1                1        0.000000
# 73                  0                     1                2        0.237272
# 124                 0                    10                1        0.520602
# 150                 0                    10                1        0.655715
# 216                 0                    16                1        0.785359
#
#      cardPresent  expirationDateKeyInMatch  isFraud  CVV_diff  \
# 21             1                         0        0         0
# 73             1                         0        0         0
# 124            0                         0        0         0
# 150            0                         0        0         0
# 216            1                         0        0         0
#
#      accountOpenMonthNum
# 21                    -4
# 73                   -12
# 124                   -6
# 150                   -6
# 216                   -7

# %%
from sklearn.cluster import KMeans

class Unsupervised(KMeans):
    def __init__(self):
        pass


class KMeans():
    def __init__(self):
        pass
    def kmeans(self, df, n_clusters, random_state):
        kmeans = KMeans(n_clusters=n_clusters, verbose=1, random_state=random_state)
        return kmeans.fit(df)
    def elbow_viz(self):
        sns.lineplot(x=clustering_scores['clusters'], y=clustering_scores['scores'])
        plt.xlim(0.5, 10)

cluster = Unsupervised()
kmeans_clusters = cluster.kmeans(df, 3, 227)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23164\3336980231.py in <cell line: 19>()
#      17
#      18 cluster = Unsupervised()
# ---> 19 kmeans_clusters = cluster.kmeans(df, 3, 227)
#
# AttributeError: 'Unsupervised' object has no attribute 'kmeans'

# %%
dir(cluster)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_check_feature_names',
#  '_check_mkl_vcomp',
#  '_check_n_features',
#  '_check_params',
#  '_check_test_data',
#  '_estimator_type',
#  '_get_param_names',
#  '_get_tags',
#  '_init_centroids',
#  '_more_tags',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_transform',
#  '_validate_center_shape',
#  '_validate_data',
#  'fit',
#  'fit_predict',
#  'fit_transform',
#  'get_params',
#  'predict',
#  'score',
#  'set_params',
#  'transform']
